# %%
#draw 5 smiley faces, and use a loop
#while loop
#or
#for i in range(5):


for i in range(5):
    print(":)")
# Out:
# :)
# :)
# :)
# :)
# :)

# %%
#get input for the number of smiley faces to print
#print that number of smiley faces


f = input("how many simley faces do you want")
for i in range(int(f)):
    print(":)")
# Out:
# how many simley faces do you want 5
# :)
# :)
# :)
# :)
# :)

# %%
x = 10

print(x)
# Out:
# 10
