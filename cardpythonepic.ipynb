# %%
num = int(input("Enter a number!"))
# Out:
# Enter a number! four
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-4f07bbf5bb4d> in <module>
# ----> 1 num = int(input("Enter a number!"))
#
# ValueError: invalid literal for int() with base 10: 'four'

# %%
try:
    num = int(input("Enter a number! "))
except:
    print("YOU DID NOT ENTER A NUMBER!")
# Out:
# Enter a number!  four
# YOU DID NOT ENTER A NUMBER!

# %%
print("Please complete the payment form for your $299 Xbox Series S \n")
#make a boolean variable to store if there was an error (initilialized with False)

x = False
try:
    card = input("VISA, MASTER, AMERICAN EXPRESS")
    number = (int(input("Enter your credit card number")))
    name = input("ur name pls")
    date = input("expiry date pls")
    code = (int(input("3 digit code pls")))
    #Ask the user to enter their credit card type
    #ask for their credit card no
    #ask for their name
    #ask for the expiry date
    #ask for the 3 digit security code
except:
    x = True
    
    
    #make error boolean variable True
if x == True:
    print("could not process purchace lol")
if x == False:
    print("congrats purchace worked lol")
#if the error boolean is true
    #print could not process payment cause error
#else
    #print the payment was processed!
# Out:
# Please complete the payment form for your $299 Xbox Series S
# VISA, MASTER, AMERICAN EXPRESS visa
# Enter your credit card number 69420
# ur name pls dude
# expiry date pls 6/9/420
# 3 digit code pls 696
# congrats purchace worked lol

# %%
# Out:
# Please complete the payment form for your $299 Xbox Series S
# VISA, MASTERCARD, UCB, AMERICAN EXPRESS?:  V3242
# Enter your credit card number:  SFIOJSOIFJOSE
# Could not process payment because of error
