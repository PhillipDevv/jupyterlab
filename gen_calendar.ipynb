# %%
True and not False or False
# Out:
# True

# %%
1) not 2) and 3) or

# %%
True and True or False

# %%
True or False

# %%
True

# %%
True or not True or False

# %%
True or False or False

# %%
True or False

# %%
True

# %%
False and False and False and True

# %%
False and False and True

# %%
False and True

# %%
False

# %%
False and False and False or True

# %%
False or True

# %%
Truee

# %%
False or False and False and False
# Out:
# False

# %%
False or False

# %%
not False and not False
# Out:
# True

# %%
True and STrue

# %%
not False and not True

# %%
True and False
# Out:
# False

# %%
not False or not True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
age = input("Give me your age")

if(int(age) >= 56 and int(age) <= 76):
    print("you are a boomer")
elif(int(age) >= 23 and int(age) <= 38):
    print("you are a millennial")
elif(int(age) >= 10 and int(age) <= 22):
    print("congrats ur a gen z")
else:
    print("your not a boomer or millennial or gen z")
# Out:
# Give me your age 40
# your not a boomer or millennial or gen z

# %%
age = input("Give me your age")

if(int(age) >= 23 and int(age) <= 38):
    print("you are a millennial")
else:
    print("you are not a millennial")
# Out:
# Give me your age 26
# you are a millennial
