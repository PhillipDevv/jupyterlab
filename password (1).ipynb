# %%
numzombies = int(input("ENTER HOW MANY ZOMBIES"))

if numzombies > 10:
    print("THAT IS A LOT")
# Out:
# ENTER HOW MANY ZOMBIES 11
# THAT IS A LOT

# %%
password = "foot"
passwordattempt = input("ENTER UR PASSWORdD")

if passwordattempt == "foot":
    print("Nice")
elif passwordattempt != "foot":
    print("UR A BOTTT")
# Out:
# ENTER UR PASSWORdD not foot
# UR A BOTTT

# %%
numzombies = int(input("ENTER HOW MANY ZOMBIES"))

if numzombies > 10:
    print("THAT IS A LOT")
elif numzombies == 10:
    print("perfect")
elif numzombies < 10:
    print("why so little")
# Out:
# ENTER HOW MANY ZOMBIES 10
# perfect

# %% [markdown]
# #
